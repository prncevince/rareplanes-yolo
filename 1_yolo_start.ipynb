# %% [markdown]
# # 1. YOLO RarePlanes Pre-Processing & Training

# %% [markdown]
# This is the first of three tutorial notebooks that implement the YOLOv5 object detection network on the RarePlanes dataset to identify aircraft characteristics of interest.
#
# In this notebook, you will be creating and detecting a custom class that combines the number of engines and propulsion type. Creating menainful custom classes can boost model performace in areas of intrest as it forces the model to differentiate in a specific way but, will also find information on how to create your own custom classes or how to use the prebuilt RarePlanes classes with YOLO.
#
# This ML pipeline uses a modified implementation of the YOLOv5 implementation found [here](https://github.com/ultralytics/yolov5). The RarePlanes dataset can be found [here](https://www.cosmiqworks.org/rareplanes/) and helper functions for the dataset can be found [here](https://github.com/aireveries/RarePlanes).
#
# This notebook contains the first four modules:
#    1. Creating a custom class to detect
#    2. Pre-processing dataset images into YOLO format
#    3. Training a YOLOv5 object detection network
#    4. Evaluating preliminary performance on tiled images

# %%
import solaris as sol
import numpy as np
import geopandas as gpd
import os
import sys
import pandas as pd
import gdal
import glob
import shapely
import shutil
import datetime
import rasterio 
import argparse
from solaris.vector.mask import footprint_mask
from solaris.vector.polygon import geojson_to_px_gdf, get_overlapping_subset
from solaris.utils.core import _check_gdf_load
from tqdm import tqdm
# Out:
# /home/ubuntu/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ubuntu/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ubuntu/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ubuntu/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ubuntu/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ubuntu/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Create Custom Classes
#
# The following functions come from the RarePlanes GitHub (link above) and are used to create custom classes using any combination of 'role','num_engines', 'propulsion', 'canards', 'num_tail_fins','wing_position', 'wing_type', 'faa_wingspan_class'. More informaiton on the classes and the dataset can be found [here](https://medium.com/the-downlinq/rareplanes-dataset-paper-and-code-release-5b0cba300a0d)

# %%
def count_unique_index(df, by):
    return df.groupby(by).size().reset_index().rename(columns={0: 'count'})

def create_custom_classes(all_annotations_geojson, geojson_dir, output_path, category_attributes):
    """ parse the geojson files and create custom classes based upon
    unique variatons of the RarePlanes attributes.
        -all_annotations_geojson (str): The path to the
        `RarePlanes_Public_All_Annotations.geojson` file.
        - geojson_dir (str): directory containing the geojson files
        for individual images or tiles
        - output_path (str): directory to output the customized geojsons. Need to provide the absolute path.
        - category_attributes (list): A list of attributes to combine
        to create a custom class.  Choose any combintaion of the following:
        ['role','num_engines', 'propulsion', 'canards', 'num_tail_fins',
       'wing_position', 'wing_type', 'faa_wingspan_class']
    :returns
        - new geojsons with a custom_id for each combination of unique
        attributes.
        -A lookup table for each classes custom_id.
    """
    os.makedirs(output_path, exist_ok=True)
    gdf = gpd.read_file(all_annotations_geojson)
    lookup_gdf = count_unique_index(gdf, category_attributes)
    lookup_gdf['custom_id'] = list(range(1, len(lookup_gdf) + 1))
    lookup_gdf.drop(columns=['count'], inplace=True)
    lookup_gdf.to_csv(os.path.join(output_path, "custom_class_lookup.csv"))
    os.chdir(geojson_dir)
    geojsons = glob.glob("*.geojson")
    for geojson in tqdm(geojsons):
        gdf = gpd.read_file(geojson)
        gdf = pd.merge(gdf, lookup_gdf, on=category_attributes, how='left')
        gdf.to_file(os.path.join(output_path, geojson), driver="GeoJSON", encoding='utf-8')

# %%
#geojsons
all_annotations_geojson = '/home/ubuntu/src/yolo_planes/wdata/RarePlanes_Public_All_Annotations.geojson'
geojson_dir_train = '/home/ubuntu/src/yolo_planes/wdata/train/geojson_aircraft_tiled/'
geojson_dir_test = '/home/ubuntu/src/yolo_planes/wdata/test/geojson_aircraft_tiled/'

#output paths
output_path_train_one = '/home/ubuntu/src/yolo_planes/geojsons_train/yolo_class_one'
output_path_test_one = '/home/ubuntu/src/yolo_planes/geojsons_test/yolo_class_one'

#classes to include in custom class (edit therese with any others you would like to add/subtract)
class_one = ['num_engines', 'propulsion']

#train
create_custom_classes(all_annotations_geojson, geojson_dir_train, output_path_train_one, class_one)

#test
create_custom_classes(all_annotations_geojson, geojson_dir_test, output_path_test_one, class_one)
# Out:
# 100%|██████████| 5815/5815 [02:32<00:00, 38.15it/s]
# 100%|██████████| 2710/2710 [01:10<00:00, 38.37it/s]

# %% [markdown]
# Once you've run this block, you can find the custom geojsons in the directory `yolo_class_one` as well as the class lookup table.

# %% [markdown]
# ### Creating YOLO Labels
#
# The following solaris function is used to convert the tiled georeferenced images to YOLOv5 lables whcich contain space delimted class id and location information of the objects of interst in each image (in this case planes).

# %%
## Training Labels to YOLO
def gdf_to_yolo(geodataframe, image, output_dir, column='single_id', im_size=(512, 512), min_overlap=0):
    """
    Convert a geodataframe containing polygons to yolo/yolt format.
    Arguments
    ---------
    geodataframe : str
        Path to a :class:`geopandas.GeoDataFrame` with a column named
        ``'geometry'``.  Can be created from a geojson with labels for unique
        objects. Can be converted to this format with
        ``geodataframe=gpd.read_file("./xView_30.geojson")``.
    image : str
        Path to a georeferenced image (ie a GeoTIFF or png created with GDAL)
        that geolocates to the same geography as the `geojson`(s). This function will also
        accept a :class:`osgeo.gdal.Dataset` or :class:`rasterio.DatasetReader`
        with georeferencing information in this argument.
    output_dir : str
        Path to an output directory where all of the yolo readable text files
        will be placed.
    column : str, optional
        The column name that contians an unique integer id for each of object
        class.
    im_size : tuple, optional
        A tuple specifying the x and y heighth of a an image.  If specified as
        ``(0,0)`` (the default,) then the size is determined automatically.
    min_overlap : float, optional
        A float value ranging from 0 to 1.  This is a percantage.  If a polygon
        does not overlap the image by at least min_overlap, the polygon is
        discarded.  i.e. 0.66 = 66%. Default value of 0.66.
    Returns
    -------
    gdf : :class:`geopandas.GeoDataFrame`.
        The txt file will be written to the output_dir, however the the output
        gdf itself is returned.
    """
    if im_size == (0, 0):
        imsize_extract = rasterio.open(image).read()
        if len(imsize_extract.shape) == 3:
            im_size = (imsize_extract.shape[1], imsize_extract.shape[2])
        else:
            im_size = (imsize_extract.shape[0], imsize_extract.shape[1])
    [x0, y0, x1, y1] = [0, 0, im_size[0], im_size[1]]
    out_coords = [[x0, y0], [x0, y1], [x1, y1], [x1, y0]]
    points = [shapely.geometry.Point(coord) for coord in out_coords]
    pix_poly = shapely.geometry.Polygon([[p.x, p.y] for p in points])
    dw = 1. / im_size[0]
    dh = 1. / im_size[1]
    header = ["column_sub_1", "x", "y", "w", "h"]
    if os.path.isdir(output_dir) is False:
        os.mkdir(output_dir)    
    img_name = image.split('/')[8]
    output = os.path.join(output_dir, img_name.split('.png')[0] + ".txt")
    gdf = geojson_to_px_gdf(geodataframe, image, precision=None)
    gdf['column_sub_1'] = gdf[column] - 1
    gdf['area'] = gdf['geometry'].area
    gdf['intersection'] = (
        gdf['geometry'].intersection(pix_poly).area / gdf['area'])
    gdf = gdf[gdf['area'] != 0]
    gdf = gdf[gdf['intersection'] >= min_overlap]
    if not gdf.empty:
        boxy = gdf['geometry'].bounds
        for _,row in boxy.iterrows():
            if row['maxx'] > im_size[0]:
                row['maxx'] = im_size[0]
            if row['minx'] < 0:
                row['minx'] = 0
            if row['maxy'] > im_size[1]:
                row['maxy'] = im_size[1]
            if row['miny'] < 0:
                row['miny'] = 0
        boxy['xmid'] = (boxy['minx'] + boxy['maxx']) / 2.0
        boxy['ymid'] = (boxy['miny'] + boxy['maxy']) / 2.0
        boxy['w0'] = (boxy['maxx'] - boxy['minx'])
        boxy['h0'] = (boxy['maxy'] - boxy['miny'])
        boxy['x'] = boxy['xmid'] * dw
        boxy['y'] = boxy['ymid'] * dh
        boxy['w'] = boxy['w0'] * dw
        boxy['h'] = boxy['h0'] * dh
        if not boxy.empty:
            gdf = gdf.join(boxy)
        gdf.to_csv(path_or_buf=output, sep=' ', columns=header, index=False, header=False)
    return gdf

# %%
truth_dir_train_name = '/home/ubuntu/src/yolo_planes/class_one/images/train'
truth_dir_test_name = '/home/ubuntu/src/yolo_planes/class_one/images/val'
truth_dir_train = os.fsencode(truth_dir_train_name)
truth_dir_test = os.fsencode(truth_dir_test_name)

geo_dir_train_one_name = '/home/ubuntu/src/yolo_planes/geojsons_train/yolo_class_one'
geo_dir_train_one = os.fsencode(geo_dir_train_one_name)

geo_dir_test_one_name = '/home/ubuntu/src/yolo_planes/geojsons_test/yolo_class_one'
geo_dir_test_one = os.fsencode(geo_dir_test_one_name)

output_dir_train_one = '/home/ubuntu/src/yolo_planes/class_one/labels/train'
os.makedirs(output_dir_train_one, exist_ok = True)

output_dir_test_one = '/home/ubuntu/src/yolo_planes/class_one/labels/val'
os.makedirs(output_dir_test_one, exist_ok = True)

# %%
geo_dir_name = geo_dir_train_one_name
geo_dir = geo_dir_train_one
truth_dir_name = truth_dir_train_name
truth_dir = truth_dir_train
output_dir = output_dir_train_one

for file in tqdm(os.listdir(geo_dir)):
    filename = os.fsdecode(file)
    if filename.endswith(".geojson"):
        geodataframe = gpd.read_file(geo_dir_name + '/' + filename)
        image_name = filename.replace('.geojson', '')     
        
        for truth in os.listdir(truth_dir):
            truth_name = os.fsdecode(truth)
            if truth_name.endswith(".png"):
                check_name = truth_name.replace('.png', '')
                if (check_name == image_name):
                    image = truth_dir_name + '/' + truth_name 
                    gdf_to_yolo(geodataframe, image, output_dir=output_dir, column='custom_id', im_size=(512, 512), min_overlap=0)
# Out:
# 100%|██████████| 5816/5816 [06:04<00:00, 15.96it/s]

# %%
geo_dir_name = geo_dir_test_one_name
geo_dir = geo_dir_test_one
truth_dir_name = truth_dir_test_name
truth_dir = truth_dir_test
output_dir = output_dir_test_one

for file in tqdm(os.listdir(geo_dir)):
    filename = os.fsdecode(file)
    if filename.endswith(".geojson"):
        geodataframe = gpd.read_file(geo_dir_name + '/' + filename)
        image_name = filename.replace('.geojson', '')     
        
        for truth in os.listdir(truth_dir):
            truth_name = os.fsdecode(truth)
            if truth_name.endswith(".png"):
                check_name = truth_name.replace('.png', '')
                if (check_name == image_name):
                    image = truth_dir_name + '/' + truth_name 
                    gdf_to_yolo(geodataframe, image, output_dir=output_dir, column='custom_id', im_size=(512, 512), min_overlap=0)
# Out:
# 100%|██████████| 2711/2711 [02:25<00:00, 18.59it/s]

# %% [markdown]
# Once you've run these three blocks, you can find the labels in the class_one labels directories—val refers to testing data.

# %% [markdown]
# ### Training the Model
#
# The first time you train the YOLOv5 model, you will need to install the packages in the next four cells. Errors with this implementation of YOLOv5 are sometimes triggered by the version of torch. More information on the dependency reqirements can be found [here](https://github.com/arichadda/yolov5/blob/master/requirements.txt).

# %%
# !conda install pytorch torchvision cudatoolkit=9.2 -c pytorch

# %%
# !pip install tensorboard

# %%
# !pip install opencv-python

# %%
# !conda install -c pytorch pytorch=1.5.1

# %% [markdown]
# The following is the training command for YOLO—on this EC2 machine, training takes roughly 4 - 5 hours. If you are using a custom class, you will have to edit the `.yaml` file in data with the class specific information. Addtionally, if you would like to use another version of the model, you can specifiy a different `.yaml` file from the models directory.

# %%
# !python train.py --img 512 --batch 18 --epochs 100 --device 0 --data ./data/class_one.yaml --cfg ./models/yolov5l.yaml --weights '' --name yolov5l_rareplanes

# %%
# !mv ./runs/exp0_yolov5l_rareplanes ./runs/class_one_yolov5l

# %% [markdown]
# ### Running Inference & Preliminary Evaluaiton
#
# The following command is used to run the inference pipeline. The weights used are those from the best epoch in training. Increasing the confidence will increase precision while decreasing recall. Also, make sure the save text flag is included as the YOLO labels output by inference will be necessary for the rest of the evaluation pipeline

# %%
# !python detect.py --weights ./runs/class_one_yolov5l/weights/best_yolov5l_rareplanes.pt --img 512 --conf 0.4 --source ../class_one/images/val/ --save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=512, iou_thres=0.5, output='inference/output', save_txt=True, source='../class_one/images/val/', update=False, view_img=False, weights=['./runs/class_one_yolov5l/weights/best_yolov5l_rareplanes.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16160MB)
#
# Fusing layers... Model Summary: 236 layers, 4.74024e+07 parameters, 4.48868e+07 gradients
# image 1/2710 ../class_one/images/val/105_104001003108D900_tile_47.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 2/2710 ../class_one/images/val/105_104001003108D900_tile_51.png: 512x512 3 2,1,propeller,3s, Done. (0.022s)
# image 3/2710 ../class_one/images/val/105_104001003108D900_tile_53.png: 512x512 4 2,1,propeller,3s, Done. (0.022s)
# image 4/2710 ../class_one/images/val/105_104001003108D900_tile_55.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 5/2710 ../class_one/images/val/105_104001003108D900_tile_56.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 6/2710 ../class_one/images/val/105_104001003108D900_tile_57.png: 512x512 6 2,1,propeller,3s, Done. (0.022s)
# image 7/2710 ../class_one/images/val/105_104001003108D900_tile_58.png: 512x512 3 2,1,propeller,3s, Done. (0.023s)
# image 8/2710 ../class_one/images/val/105_104001003108D900_tile_61.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 9/2710 ../class_one/images/val/105_104001003108D900_tile_62.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 10/2710 ../class_one/images/val/105_104001003108D900_tile_66.png: 512x512 3 2,1,propeller,3s, Done. (0.022s)
# image 11/2710 ../class_one/images/val/105_104001003108D900_tile_78.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 12/2710 ../class_one/images/val/105_104001003108D900_tile_82.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 13/2710 ../class_one/images/val/105_104001003108D900_tile_86.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 14/2710 ../class_one/images/val/106_104001003D8DB300_tile_109.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 15/2710 ../class_one/images/val/106_104001003D8DB300_tile_110.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 16/2710 ../class_one/images/val/106_104001003D8DB300_tile_42.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 17/2710 ../class_one/images/val/106_104001003D8DB300_tile_43.png: 512x512 1 2,1,propeller,3s, 3 3,2,jet,4s, Done. (0.022s)
# image 18/2710 ../class_one/images/val/106_104001003D8DB300_tile_53.png: 512x512 8 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 19/2710 ../class_one/images/val/106_104001003D8DB300_tile_54.png: 512x512 1 2,1,propeller,3s, 9 3,2,jet,4s, Done. (0.022s)
# image 20/2710 ../class_one/images/val/106_104001003D8DB300_tile_64.png: 512x512 1 2,1,propeller,3s, 3 3,2,jet,4s, Done. (0.022s)
# image 21/2710 ../class_one/images/val/106_104001003D8DB300_tile_65.png: 512x512 4 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 22/2710 ../class_one/images/val/106_104001003D8DB300_tile_66.png: 512x512 4 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 23/2710 ../class_one/images/val/106_104001003D8DB300_tile_75.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 24/2710 ../class_one/images/val/106_104001003D8DB300_tile_76.png: 512x512 6 2,1,propeller,3s, Done. (0.022s)
# image 25/2710 ../class_one/images/val/106_104001003D8DB300_tile_85.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 26/2710 ../class_one/images/val/106_104001003D8DB300_tile_86.png: 512x512 5 2,1,propeller,3s, 5 3,2,jet,4s, 3 4,2,propeller,5s, Done. (0.022s)
# image 27/2710 ../class_one/images/val/106_104001003D8DB300_tile_87.png: 512x512 10 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.023s)
# image 28/2710 ../class_one/images/val/106_104001003D8DB300_tile_88.png: 512x512 1 2,1,propeller,3s, Done. (0.024s)
# image 29/2710 ../class_one/images/val/106_104001003D8DB300_tile_97.png: 512x512 4 2,1,propeller,3s, 3 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 30/2710 ../class_one/images/val/106_104001003D8DB300_tile_98.png: 512x512 7 2,1,propeller,3s, 5 3,2,jet,4s, 7 4,2,propeller,5s, Done. (0.022s)
# image 31/2710 ../class_one/images/val/106_104001003D8DB300_tile_99.png: 512x512 2 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 32/2710 ../class_one/images/val/108_10400100457A8A00_tile_108.png: 512x512 4 2,1,propeller,3s, Done. (0.022s)
# image 33/2710 ../class_one/images/val/108_10400100457A8A00_tile_109.png: 512x512 3 2,1,propeller,3s, Done. (0.022s)
# image 34/2710 ../class_one/images/val/108_10400100457A8A00_tile_27.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 35/2710 ../class_one/images/val/108_10400100457A8A00_tile_37.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 36/2710 ../class_one/images/val/108_10400100457A8A00_tile_38.png: 512x512 8 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.022s)
# image 37/2710 ../class_one/images/val/108_10400100457A8A00_tile_39.png: 512x512 16 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.022s)
# image 38/2710 ../class_one/images/val/108_10400100457A8A00_tile_48.png: 512x512 26 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.022s)
# image 39/2710 ../class_one/images/val/108_10400100457A8A00_tile_49.png: 512x512 36 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.023s)
# image 40/2710 ../class_one/images/val/108_10400100457A8A00_tile_58.png: 512x512 20 2,1,propeller,3s, Done. (0.023s)
# image 41/2710 ../class_one/images/val/108_10400100457A8A00_tile_59.png: 512x512 20 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 42/2710 ../class_one/images/val/108_10400100457A8A00_tile_68.png: 512x512 22 2,1,propeller,3s, 4 4,2,propeller,5s, Done. (0.023s)
# image 43/2710 ../class_one/images/val/108_10400100457A8A00_tile_69.png: 512x512 10 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.023s)
# image 44/2710 ../class_one/images/val/108_10400100457A8A00_tile_78.png: 512x512 3 2,1,propeller,3s, 4 4,2,propeller,5s, Done. (0.022s)
# image 45/2710 ../class_one/images/val/108_10400100457A8A00_tile_79.png: 512x512 2 4,2,propeller,5s, Done. (0.022s)
# image 46/2710 ../class_one/images/val/108_10400100457A8A00_tile_88.png: 512x512 5 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.022s)
# image 47/2710 ../class_one/images/val/108_10400100457A8A00_tile_89.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 48/2710 ../class_one/images/val/108_10400100457A8A00_tile_98.png: 512x512 5 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.022s)
# image 49/2710 ../class_one/images/val/108_10400100457A8A00_tile_99.png: 512x512 1 1,1,jet,2s, 2 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 50/2710 ../class_one/images/val/10_104001002E88FE00_tile_10.png: 512x512 3 2,1,propeller,3s, 1 3,2,jet,4s, Done. (0.023s)
# image 51/2710 ../class_one/images/val/10_104001002E88FE00_tile_11.png: 512x512 2 2,1,propeller,3s, Done. (0.024s)
# image 52/2710 ../class_one/images/val/10_104001002E88FE00_tile_114.png: 512x512 6 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 53/2710 ../class_one/images/val/10_104001002E88FE00_tile_131.png: 512x512 3 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 54/2710 ../class_one/images/val/10_104001002E88FE00_tile_197.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 55/2710 ../class_one/images/val/10_104001002E88FE00_tile_198.png: 512x512 2 4,2,propeller,5s, Done. (0.022s)
# image 56/2710 ../class_one/images/val/10_104001002E88FE00_tile_202.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 57/2710 ../class_one/images/val/10_104001002E88FE00_tile_203.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 58/2710 ../class_one/images/val/10_104001002E88FE00_tile_214.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 59/2710 ../class_one/images/val/10_104001002E88FE00_tile_215.png: 512x512 2 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 60/2710 ../class_one/images/val/10_104001002E88FE00_tile_27.png: 512x512 3 2,1,propeller,3s, 1 3,2,jet,4s, 3 4,2,propeller,5s, Done. (0.022s)
# image 61/2710 ../class_one/images/val/10_104001002E88FE00_tile_28.png: 512x512 4 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.022s)
# image 62/2710 ../class_one/images/val/10_104001002E88FE00_tile_45.png: 512x512 5 2,1,propeller,3s, Done. (0.022s)
# image 63/2710 ../class_one/images/val/10_104001002E88FE00_tile_74.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 64/2710 ../class_one/images/val/10_104001002E88FE00_tile_75.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 65/2710 ../class_one/images/val/10_104001002E88FE00_tile_77.png: 512x512 2 2,1,propeller,3s, Done. (0.023s)
# image 66/2710 ../class_one/images/val/10_104001002E88FE00_tile_78.png: 512x512 5 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.023s)
# image 67/2710 ../class_one/images/val/10_104001002E88FE00_tile_79.png: 512x512 2 4,2,propeller,5s, Done. (0.023s)
# image 68/2710 ../class_one/images/val/10_104001002E88FE00_tile_95.png: 512x512 5 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.022s)
# image 69/2710 ../class_one/images/val/10_104001002E88FE00_tile_96.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 70/2710 ../class_one/images/val/10_104001002E88FE00_tile_97.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 71/2710 ../class_one/images/val/111_10400100356A6A00_tile_316.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 72/2710 ../class_one/images/val/111_10400100356A6A00_tile_341.png: 512x512 9 2,1,propeller,3s, Done. (0.022s)
# image 73/2710 ../class_one/images/val/111_10400100356A6A00_tile_342.png: 512x512 8 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 74/2710 ../class_one/images/val/111_10400100356A6A00_tile_366.png: 512x512 3 2,1,propeller,3s, Done. (0.022s)
# image 75/2710 ../class_one/images/val/111_10400100356A6A00_tile_367.png: 512x512 6 2,1,propeller,3s, Done. (0.023s)
# image 76/2710 ../class_one/images/val/111_10400100356A6A00_tile_368.png: 512x512 5 2,1,propeller,3s, Done. (0.023s)
# image 77/2710 ../class_one/images/val/111_10400100356A6A00_tile_392.png: 512x512 8 2,1,propeller,3s, 1 3,2,jet,4s, Done. (0.024s)
# image 78/2710 ../class_one/images/val/111_10400100356A6A00_tile_393.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 79/2710 ../class_one/images/val/111_10400100356A6A00_tile_401.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 80/2710 ../class_one/images/val/111_10400100356A6A00_tile_402.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 81/2710 ../class_one/images/val/113_104001003D8DB300_tile_106.png: 512x512 4 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 82/2710 ../class_one/images/val/113_104001003D8DB300_tile_107.png: 512x512 3 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 83/2710 ../class_one/images/val/113_104001003D8DB300_tile_118.png: 512x512 2 2,1,propeller,3s, 2 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 84/2710 ../class_one/images/val/113_104001003D8DB300_tile_119.png: 512x512 4 3,2,jet,4s, Done. (0.022s)
# image 85/2710 ../class_one/images/val/113_104001003D8DB300_tile_131.png: 512x512 1 0,0,unpowered,1s, 1 2,1,propeller,3s, 2 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 86/2710 ../class_one/images/val/113_104001003D8DB300_tile_132.png: 512x512 Done. (0.021s)
# image 87/2710 ../class_one/images/val/113_104001003D8DB300_tile_23.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 88/2710 ../class_one/images/val/113_104001003D8DB300_tile_24.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 89/2710 ../class_one/images/val/113_104001003D8DB300_tile_34.png: 512x512 2 4,2,propeller,5s, Done. (0.022s)
# image 90/2710 ../class_one/images/val/113_104001003D8DB300_tile_35.png: 512x512 1 0,0,unpowered,1s, 1 1,1,jet,2s, 12 2,1,propeller,3s, 1 3,2,jet,4s, 6 4,2,propeller,5s, Done. (0.023s)
# image 91/2710 ../class_one/images/val/113_104001003D8DB300_tile_36.png: 512x512 2 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 92/2710 ../class_one/images/val/113_104001003D8DB300_tile_46.png: 512x512 1 0,0,unpowered,1s, 2 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 93/2710 ../class_one/images/val/113_104001003D8DB300_tile_47.png: 512x512 5 2,1,propeller,3s, 4 4,2,propeller,5s, Done. (0.022s)
# image 94/2710 ../class_one/images/val/113_104001003D8DB300_tile_48.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 95/2710 ../class_one/images/val/113_104001003D8DB300_tile_57.png: 512x512 3 2,1,propeller,3s, 1 3,2,jet,4s, 3 4,2,propeller,5s, Done. (0.022s)
# image 96/2710 ../class_one/images/val/113_104001003D8DB300_tile_58.png: 512x512 1 0,0,unpowered,1s, 4 2,1,propeller,3s, 1 3,2,jet,4s, 6 4,2,propeller,5s, Done. (0.022s)
# image 97/2710 ../class_one/images/val/113_104001003D8DB300_tile_59.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 98/2710 ../class_one/images/val/113_104001003D8DB300_tile_69.png: 512x512 2 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 99/2710 ../class_one/images/val/113_104001003D8DB300_tile_70.png: 512x512 20 2,1,propeller,3s, 5 4,2,propeller,5s, Done. (0.022s)
# image 100/2710 ../class_one/images/val/113_104001003D8DB300_tile_71.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 101/2710 ../class_one/images/val/113_104001003D8DB300_tile_82.png: 512x512 7 2,1,propeller,3s, 5 4,2,propeller,5s, Done. (0.023s)
# image 102/2710 ../class_one/images/val/113_104001003D8DB300_tile_83.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.023s)
# image 103/2710 ../class_one/images/val/113_104001003D8DB300_tile_94.png: 512x512 13 2,1,propeller,3s, 1 3,2,jet,4s, 4 4,2,propeller,5s, Done. (0.024s)
# image 104/2710 ../class_one/images/val/113_104001003D8DB300_tile_95.png: 512x512 7 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.023s)
# image 105/2710 ../class_one/images/val/113_104001003D8DB300_tile_96.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.024s)
# image 106/2710 ../class_one/images/val/115_104001004B8E2D00_tile_1007.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 107/2710 ../class_one/images/val/115_104001004B8E2D00_tile_1034.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 108/2710 ../class_one/images/val/115_104001004B8E2D00_tile_1039.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 109/2710 ../class_one/images/val/115_104001004B8E2D00_tile_1040.png: 512x512 1 1,1,jet,2s, 1 2,1,propeller,3s, 3 3,2,jet,4s, 1 4,2,propeller,5s, 1 6,4,jet,7s, Done. (0.022s)
# image 110/2710 ../class_one/images/val/115_104001004B8E2D00_tile_1066.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 111/2710 ../class_one/images/val/115_104001004B8E2D00_tile_1067.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 112/2710 ../class_one/images/val/115_104001004B8E2D00_tile_155.png: 512x512 2 4,2,propeller,5s, Done. (0.022s)
# image 113/2710 ../class_one/images/val/115_104001004B8E2D00_tile_156.png: 512x512 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.023s)
# image 114/2710 ../class_one/images/val/115_104001004B8E2D00_tile_163.png: 512x512 Done. (0.021s)
# image 115/2710 ../class_one/images/val/115_104001004B8E2D00_tile_182.png: 512x512 3 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 116/2710 ../class_one/images/val/115_104001004B8E2D00_tile_183.png: 512x512 2 3,2,jet,4s, 3 4,2,propeller,5s, Done. (0.022s)
# image 117/2710 ../class_one/images/val/115_104001004B8E2D00_tile_208.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 118/2710 ../class_one/images/val/115_104001004B8E2D00_tile_209.png: 512x512 4 2,1,propeller,3s, 1 3,2,jet,4s, Done. (0.022s)
# image 119/2710 ../class_one/images/val/115_104001004B8E2D00_tile_235.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, Done. (0.022s)
# image 120/2710 ../class_one/images/val/115_104001004B8E2D00_tile_236.png: 512x512 1 2,1,propeller,3s, 2 3,2,jet,4s, Done. (0.022s)
# image 121/2710 ../class_one/images/val/115_104001004B8E2D00_tile_262.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 122/2710 ../class_one/images/val/115_104001004B8E2D00_tile_288.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 123/2710 ../class_one/images/val/115_104001004B8E2D00_tile_291.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 124/2710 ../class_one/images/val/115_104001004B8E2D00_tile_292.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 125/2710 ../class_one/images/val/115_104001004B8E2D00_tile_319.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 126/2710 ../class_one/images/val/115_104001004B8E2D00_tile_346.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 127/2710 ../class_one/images/val/115_104001004B8E2D00_tile_373.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 128/2710 ../class_one/images/val/115_104001004B8E2D00_tile_499.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 129/2710 ../class_one/images/val/115_104001004B8E2D00_tile_500.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 130/2710 ../class_one/images/val/115_104001004B8E2D00_tile_526.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 131/2710 ../class_one/images/val/115_104001004B8E2D00_tile_527.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 132/2710 ../class_one/images/val/115_104001004B8E2D00_tile_552.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 133/2710 ../class_one/images/val/115_104001004B8E2D00_tile_553.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 134/2710 ../class_one/images/val/115_104001004B8E2D00_tile_631.png: 512x512 2 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.022s)
# image 135/2710 ../class_one/images/val/115_104001004B8E2D00_tile_632.png: 512x512 1 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.022s)
# image 136/2710 ../class_one/images/val/115_104001004B8E2D00_tile_657.png: 512x512 1 6,4,jet,7s, Done. (0.022s)
# image 137/2710 ../class_one/images/val/115_104001004B8E2D00_tile_658.png: 512x512 3 6,4,jet,7s, Done. (0.022s)
# image 138/2710 ../class_one/images/val/115_104001004B8E2D00_tile_663.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 139/2710 ../class_one/images/val/115_104001004B8E2D00_tile_666.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 140/2710 ../class_one/images/val/115_104001004B8E2D00_tile_667.png: 512x512 3 3,2,jet,4s, Done. (0.022s)
# image 141/2710 ../class_one/images/val/115_104001004B8E2D00_tile_668.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 142/2710 ../class_one/images/val/115_104001004B8E2D00_tile_669.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 143/2710 ../class_one/images/val/115_104001004B8E2D00_tile_670.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 144/2710 ../class_one/images/val/115_104001004B8E2D00_tile_677.png: 512x512 2 1,1,jet,2s, 1 6,4,jet,7s, Done. (0.022s)
# image 145/2710 ../class_one/images/val/115_104001004B8E2D00_tile_683.png: 512x512 1 6,4,jet,7s, Done. (0.022s)
# image 146/2710 ../class_one/images/val/115_104001004B8E2D00_tile_684.png: 512x512 1 3,2,jet,4s, 2 6,4,jet,7s, Done. (0.023s)
# image 147/2710 ../class_one/images/val/115_104001004B8E2D00_tile_685.png: 512x512 2 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.024s)
# image 148/2710 ../class_one/images/val/115_104001004B8E2D00_tile_690.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 149/2710 ../class_one/images/val/115_104001004B8E2D00_tile_691.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 150/2710 ../class_one/images/val/115_104001004B8E2D00_tile_693.png: 512x512 4 3,2,jet,4s, Done. (0.022s)
# image 151/2710 ../class_one/images/val/115_104001004B8E2D00_tile_694.png: 512x512 6 3,2,jet,4s, Done. (0.022s)
# image 152/2710 ../class_one/images/val/115_104001004B8E2D00_tile_695.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 153/2710 ../class_one/images/val/115_104001004B8E2D00_tile_696.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 154/2710 ../class_one/images/val/115_104001004B8E2D00_tile_710.png: 512x512 2 6,4,jet,7s, Done. (0.022s)
# image 155/2710 ../class_one/images/val/115_104001004B8E2D00_tile_711.png: 512x512 2 6,4,jet,7s, Done. (0.022s)
# image 156/2710 ../class_one/images/val/115_104001004B8E2D00_tile_716.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 157/2710 ../class_one/images/val/115_104001004B8E2D00_tile_720.png: 512x512 5 3,2,jet,4s, Done. (0.023s)
# image 158/2710 ../class_one/images/val/115_104001004B8E2D00_tile_721.png: 512x512 5 3,2,jet,4s, Done. (0.022s)
# image 159/2710 ../class_one/images/val/115_104001004B8E2D00_tile_722.png: 512x512 3 3,2,jet,4s, Done. (0.022s)
# image 160/2710 ../class_one/images/val/115_104001004B8E2D00_tile_743.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 161/2710 ../class_one/images/val/115_104001004B8E2D00_tile_747.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 162/2710 ../class_one/images/val/115_104001004B8E2D00_tile_879.png: 512x512 2 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 163/2710 ../class_one/images/val/115_104001004B8E2D00_tile_880.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 164/2710 ../class_one/images/val/115_104001004B8E2D00_tile_881.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 165/2710 ../class_one/images/val/115_104001004B8E2D00_tile_901.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 166/2710 ../class_one/images/val/115_104001004B8E2D00_tile_902.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 167/2710 ../class_one/images/val/115_104001004B8E2D00_tile_906.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 168/2710 ../class_one/images/val/115_104001004B8E2D00_tile_907.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 169/2710 ../class_one/images/val/115_104001004B8E2D00_tile_908.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 170/2710 ../class_one/images/val/115_104001004B8E2D00_tile_928.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 171/2710 ../class_one/images/val/115_104001004B8E2D00_tile_929.png: 512x512 3 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 172/2710 ../class_one/images/val/115_104001004B8E2D00_tile_930.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 173/2710 ../class_one/images/val/115_104001004B8E2D00_tile_932.png: 512x512 2 2,1,propeller,3s, 5 4,2,propeller,5s, Done. (0.022s)
# image 174/2710 ../class_one/images/val/115_104001004B8E2D00_tile_956.png: 512x512 2 2,1,propeller,3s, 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 175/2710 ../class_one/images/val/115_104001004B8E2D00_tile_957.png: 512x512 1 1,1,jet,2s, 4 3,2,jet,4s, Done. (0.022s)
# image 176/2710 ../class_one/images/val/115_104001004B8E2D00_tile_958.png: 512x512 1 0,0,unpowered,1s, 5 1,1,jet,2s, 2 2,1,propeller,3s, 3 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.022s)
# image 177/2710 ../class_one/images/val/115_104001004B8E2D00_tile_959.png: 512x512 7 1,1,jet,2s, 1 2,1,propeller,3s, 3 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.023s)
# image 178/2710 ../class_one/images/val/115_104001004B8E2D00_tile_984.png: 512x512 1 1,1,jet,2s, 2 3,2,jet,4s, Done. (0.022s)
# image 179/2710 ../class_one/images/val/115_104001004B8E2D00_tile_985.png: 512x512 3 1,1,jet,2s, 1 2,1,propeller,3s, 3 3,2,jet,4s, Done. (0.022s)
# image 180/2710 ../class_one/images/val/115_104001004B8E2D00_tile_986.png: 512x512 Done. (0.021s)
# image 181/2710 ../class_one/images/val/116_1040010012CE4600_tile_113.png: 512x512 6 2,1,propeller,3s, Done. (0.022s)
# image 182/2710 ../class_one/images/val/116_1040010012CE4600_tile_122.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 183/2710 ../class_one/images/val/116_1040010012CE4600_tile_123.png: 512x512 6 2,1,propeller,3s, Done. (0.022s)
# image 184/2710 ../class_one/images/val/116_1040010012CE4600_tile_124.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 185/2710 ../class_one/images/val/116_1040010012CE4600_tile_125.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 186/2710 ../class_one/images/val/116_1040010012CE4600_tile_134.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.023s)
# image 187/2710 ../class_one/images/val/116_1040010012CE4600_tile_135.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 188/2710 ../class_one/images/val/116_1040010012CE4600_tile_166.png: 512x512 1 2,1,propeller,3s, Done. (0.024s)
# image 189/2710 ../class_one/images/val/116_1040010012CE4600_tile_176.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 190/2710 ../class_one/images/val/116_1040010012CE4600_tile_76.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 191/2710 ../class_one/images/val/116_1040010012CE4600_tile_84.png: 512x512 5 2,1,propeller,3s, Done. (0.022s)
# image 192/2710 ../class_one/images/val/116_1040010012CE4600_tile_85.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 193/2710 ../class_one/images/val/116_1040010012CE4600_tile_94.png: 512x512 9 2,1,propeller,3s, Done. (0.023s)
# image 194/2710 ../class_one/images/val/116_1040010012CE4600_tile_95.png: 512x512 7 2,1,propeller,3s, Done. (0.023s)
# image 195/2710 ../class_one/images/val/116_10400100166EBE00_tile_122.png: 512x512 2 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 196/2710 ../class_one/images/val/116_10400100166EBE00_tile_123.png: 512x512 3 2,1,propeller,3s, Done. (0.022s)
# image 197/2710 ../class_one/images/val/116_10400100166EBE00_tile_125.png: 512x512 10 2,1,propeller,3s, Done. (0.022s)
# image 198/2710 ../class_one/images/val/116_10400100166EBE00_tile_126.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 199/2710 ../class_one/images/val/116_10400100166EBE00_tile_137.png: 512x512 4 2,1,propeller,3s, Done. (0.022s)
# image 200/2710 ../class_one/images/val/116_10400100166EBE00_tile_138.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 201/2710 ../class_one/images/val/116_10400100166EBE00_tile_159.png: 512x512 Done. (0.022s)
# image 202/2710 ../class_one/images/val/116_10400100166EBE00_tile_160.png: 512x512 Done. (0.022s)
# image 203/2710 ../class_one/images/val/116_10400100166EBE00_tile_171.png: 512x512 1 2,1,propeller,3s, Done. (0.024s)
# image 204/2710 ../class_one/images/val/116_10400100166EBE00_tile_172.png: 512x512 Done. (0.022s)
# image 205/2710 ../class_one/images/val/116_10400100166EBE00_tile_183.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 206/2710 ../class_one/images/val/116_10400100166EBE00_tile_185.png: 512x512 1 7,4,propeller,8s, Done. (0.022s)
# image 207/2710 ../class_one/images/val/116_10400100166EBE00_tile_208.png: 512x512 Done. (0.021s)
# image 208/2710 ../class_one/images/val/116_1040010017731200_tile_112.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 209/2710 ../class_one/images/val/116_1040010017731200_tile_113.png: 512x512 2 2,1,propeller,3s, Done. (0.023s)
# image 210/2710 ../class_one/images/val/116_1040010017731200_tile_124.png: 512x512 2 2,1,propeller,3s, Done. (0.023s)
# image 211/2710 ../class_one/images/val/116_1040010017731200_tile_125.png: 512x512 11 2,1,propeller,3s, Done. (0.022s)
# image 212/2710 ../class_one/images/val/116_1040010017731200_tile_126.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 213/2710 ../class_one/images/val/116_1040010017731200_tile_137.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 214/2710 ../class_one/images/val/116_1040010017731200_tile_159.png: 512x512 1 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.023s)
# image 215/2710 ../class_one/images/val/116_1040010017731200_tile_160.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 216/2710 ../class_one/images/val/116_1040010017731200_tile_171.png: 512x512 Done. (0.021s)
# image 217/2710 ../class_one/images/val/116_1040010017731200_tile_184.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 218/2710 ../class_one/images/val/116_1040010017731200_tile_185.png: 512x512 1 4,2,propeller,5s, Done. (0.023s)
# image 219/2710 ../class_one/images/val/117_104001000F945200_tile_116.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.023s)
# image 220/2710 ../class_one/images/val/117_104001000F945200_tile_133.png: 512x512 1 4,2,propeller,5s, Done. (0.023s)
# image 221/2710 ../class_one/images/val/117_104001000F945200_tile_151.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 222/2710 ../class_one/images/val/117_104001000F945200_tile_152.png: 512x512 3 2,1,propeller,3s, Done. (0.022s)
# image 223/2710 ../class_one/images/val/117_104001000F945200_tile_169.png: 512x512 1 1,1,jet,2s, Done. (0.023s)
# image 224/2710 ../class_one/images/val/117_104001000F945200_tile_218.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 225/2710 ../class_one/images/val/117_104001000F945200_tile_235.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 226/2710 ../class_one/images/val/118_10400100213D3100_tile_1064.png: 512x512 2 4,2,propeller,5s, Done. (0.023s)
# image 227/2710 ../class_one/images/val/118_10400100213D3100_tile_1065.png: 512x512 2 4,2,propeller,5s, Done. (0.023s)
# image 228/2710 ../class_one/images/val/118_10400100213D3100_tile_258.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 229/2710 ../class_one/images/val/118_10400100213D3100_tile_292.png: 512x512 1 3,2,jet,4s, Done. (0.024s)
# image 230/2710 ../class_one/images/val/118_10400100213D3100_tile_359.png: 512x512 1 3,2,jet,4s, Done. (0.024s)
# image 231/2710 ../class_one/images/val/118_10400100213D3100_tile_450.png: 512x512 1 4,2,propeller,5s, Done. (0.024s)
# image 232/2710 ../class_one/images/val/118_10400100213D3100_tile_452.png: 512x512 1 4,2,propeller,5s, Done. (0.023s)
# image 233/2710 ../class_one/images/val/118_10400100213D3100_tile_453.png: 512x512 3 4,2,propeller,5s, Done. (0.023s)
# image 234/2710 ../class_one/images/val/118_10400100213D3100_tile_484.png: 512x512 1 4,2,propeller,5s, Done. (0.023s)
# image 235/2710 ../class_one/images/val/118_10400100213D3100_tile_486.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.023s)
# image 236/2710 ../class_one/images/val/118_10400100213D3100_tile_487.png: 512x512 1 3,2,jet,4s, 4 4,2,propeller,5s, Done. (0.023s)
# image 237/2710 ../class_one/images/val/118_10400100213D3100_tile_492.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 238/2710 ../class_one/images/val/118_10400100213D3100_tile_493.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 239/2710 ../class_one/images/val/118_10400100213D3100_tile_494.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 240/2710 ../class_one/images/val/118_10400100213D3100_tile_498.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 241/2710 ../class_one/images/val/118_10400100213D3100_tile_499.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 242/2710 ../class_one/images/val/118_10400100213D3100_tile_526.png: 512x512 1 4,2,propeller,5s, Done. (0.024s)
# image 243/2710 ../class_one/images/val/118_10400100213D3100_tile_527.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 244/2710 ../class_one/images/val/118_10400100213D3100_tile_528.png: 512x512 2 3,2,jet,4s, Done. (0.024s)
# image 245/2710 ../class_one/images/val/118_10400100213D3100_tile_532.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 246/2710 ../class_one/images/val/118_10400100213D3100_tile_533.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 247/2710 ../class_one/images/val/118_10400100213D3100_tile_573.png: 512x512 1 2,1,propeller,3s, 2 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.023s)
# image 248/2710 ../class_one/images/val/118_10400100213D3100_tile_574.png: 512x512 1 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 249/2710 ../class_one/images/val/118_10400100213D3100_tile_606.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 250/2710 ../class_one/images/val/118_10400100213D3100_tile_607.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 251/2710 ../class_one/images/val/118_10400100213D3100_tile_628.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 252/2710 ../class_one/images/val/118_10400100213D3100_tile_629.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 253/2710 ../class_one/images/val/118_10400100213D3100_tile_652.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 254/2710 ../class_one/images/val/118_10400100213D3100_tile_653.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 255/2710 ../class_one/images/val/118_10400100213D3100_tile_659.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 256/2710 ../class_one/images/val/118_10400100213D3100_tile_662.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 257/2710 ../class_one/images/val/118_10400100213D3100_tile_663.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 258/2710 ../class_one/images/val/118_10400100213D3100_tile_686.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 259/2710 ../class_one/images/val/118_10400100213D3100_tile_687.png: 512x512 3 3,2,jet,4s, Done. (0.022s)
# image 260/2710 ../class_one/images/val/118_10400100213D3100_tile_693.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 261/2710 ../class_one/images/val/118_10400100213D3100_tile_697.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 262/2710 ../class_one/images/val/118_10400100213D3100_tile_721.png: 512x512 1 2,1,propeller,3s, 5 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 263/2710 ../class_one/images/val/118_10400100213D3100_tile_722.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.022s)
# image 264/2710 ../class_one/images/val/118_10400100213D3100_tile_729.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 265/2710 ../class_one/images/val/118_10400100213D3100_tile_731.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 266/2710 ../class_one/images/val/118_10400100213D3100_tile_755.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, Done. (0.023s)
# image 267/2710 ../class_one/images/val/118_10400100213D3100_tile_756.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 268/2710 ../class_one/images/val/118_10400100213D3100_tile_763.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 269/2710 ../class_one/images/val/118_10400100213D3100_tile_776.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 270/2710 ../class_one/images/val/118_10400100213D3100_tile_789.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.023s)
# image 271/2710 ../class_one/images/val/118_10400100213D3100_tile_790.png: 512x512 1 4,2,propeller,5s, Done. (0.024s)
# image 272/2710 ../class_one/images/val/118_10400100213D3100_tile_823.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.023s)
# image 273/2710 ../class_one/images/val/119_104001003EA38900_tile_70.png: 512x512 5 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 274/2710 ../class_one/images/val/119_104001003EA38900_tile_71.png: 512x512 15 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 275/2710 ../class_one/images/val/119_104001003EA38900_tile_83.png: 512x512 3 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.023s)
# image 276/2710 ../class_one/images/val/119_104001003EA38900_tile_84.png: 512x512 9 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.024s)
# image 277/2710 ../class_one/images/val/11_1040010016C34900_tile_123.png: 512x512 1 4,2,propeller,5s, Done. (0.023s)
# image 278/2710 ../class_one/images/val/11_1040010016C34900_tile_136.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 279/2710 ../class_one/images/val/11_1040010016C34900_tile_229.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 280/2710 ../class_one/images/val/11_1040010016C34900_tile_241.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 281/2710 ../class_one/images/val/11_1040010016C34900_tile_242.png: 512x512 Done. (0.021s)
# image 282/2710 ../class_one/images/val/11_1040010016C34900_tile_254.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, 3 4,2,propeller,5s, 1 7,4,propeller,8s, Done. (0.022s)
# image 283/2710 ../class_one/images/val/11_1040010016C34900_tile_255.png: 512x512 Done. (0.021s)
# image 284/2710 ../class_one/images/val/11_1040010016C34900_tile_267.png: 512x512 Done. (0.021s)
# image 285/2710 ../class_one/images/val/11_1040010016C34900_tile_279.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 286/2710 ../class_one/images/val/11_1040010016C34900_tile_291.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 287/2710 ../class_one/images/val/11_1040010016C34900_tile_292.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 288/2710 ../class_one/images/val/11_1040010016C34900_tile_304.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 289/2710 ../class_one/images/val/11_1040010016C34900_tile_328.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 290/2710 ../class_one/images/val/11_1040010016C34900_tile_329.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 291/2710 ../class_one/images/val/11_1040010016C34900_tile_341.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 292/2710 ../class_one/images/val/11_1040010016C34900_tile_342.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 293/2710 ../class_one/images/val/11_1040010033758F00_tile_118.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 294/2710 ../class_one/images/val/11_1040010033758F00_tile_119.png: 512x512 2 4,2,propeller,5s, Done. (0.022s)
# image 295/2710 ../class_one/images/val/11_1040010033758F00_tile_129.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 296/2710 ../class_one/images/val/11_1040010033758F00_tile_130.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 297/2710 ../class_one/images/val/11_1040010033758F00_tile_140.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 298/2710 ../class_one/images/val/11_1040010033758F00_tile_150.png: 512x512 4 2,1,propeller,3s, Done. (0.022s)
# image 299/2710 ../class_one/images/val/11_1040010033758F00_tile_151.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 300/2710 ../class_one/images/val/11_1040010033758F00_tile_182.png: 512x512 1 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.022s)
# image 301/2710 ../class_one/images/val/11_1040010033758F00_tile_183.png: 512x512 Done. (0.022s)
# image 302/2710 ../class_one/images/val/11_1040010033758F00_tile_193.png: 512x512 1 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.023s)
# image 303/2710 ../class_one/images/val/11_1040010033758F00_tile_194.png: 512x512 Done. (0.022s)
# image 304/2710 ../class_one/images/val/11_1040010033758F00_tile_214.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.023s)
# image 305/2710 ../class_one/images/val/11_1040010033758F00_tile_235.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.023s)
# image 306/2710 ../class_one/images/val/11_1040010033758F00_tile_246.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 307/2710 ../class_one/images/val/124_104001001F2A5700_tile_108.png: 512x512 2 2,1,propeller,3s, 1 3,2,jet,4s, 3 4,2,propeller,5s, Done. (0.022s)
# image 308/2710 ../class_one/images/val/124_104001001F2A5700_tile_124.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.023s)
# image 309/2710 ../class_one/images/val/124_104001001F2A5700_tile_125.png: 512x512 28 2,1,propeller,3s, 3 3,2,jet,4s, 6 4,2,propeller,5s, Done. (0.023s)
# image 310/2710 ../class_one/images/val/124_104001001F2A5700_tile_126.png: 512x512 13 2,1,propeller,3s, Done. (0.023s)
# image 311/2710 ../class_one/images/val/124_104001001F2A5700_tile_142.png: 512x512 19 2,1,propeller,3s, 5 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.023s)
# image 312/2710 ../class_one/images/val/124_104001001F2A5700_tile_143.png: 512x512 33 2,1,propeller,3s, 3 4,2,propeller,5s, Done. (0.024s)
# image 313/2710 ../class_one/images/val/124_104001001F2A5700_tile_159.png: 512x512 2 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.024s)
# image 314/2710 ../class_one/images/val/124_104001001F2A5700_tile_160.png: 512x512 11 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 315/2710 ../class_one/images/val/124_104001001F2A5700_tile_178.png: 512x512 5 4,2,propeller,5s, Done. (0.023s)
# image 316/2710 ../class_one/images/val/124_104001001F2A5700_tile_179.png: 512x512 3 4,2,propeller,5s, Done. (0.023s)
# image 317/2710 ../class_one/images/val/124_104001001F2A5700_tile_194.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 318/2710 ../class_one/images/val/124_104001001F2A5700_tile_195.png: 512x512 2 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.022s)
# image 319/2710 ../class_one/images/val/124_104001001F2A5700_tile_196.png: 512x512 1 2,1,propeller,3s, Done. (0.023s)
# image 320/2710 ../class_one/images/val/124_104001001F2A5700_tile_212.png: 512x512 3 2,1,propeller,3s, 3 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.023s)
# image 321/2710 ../class_one/images/val/124_104001001F2A5700_tile_213.png: 512x512 2 2,1,propeller,3s, Done. (0.024s)
# image 322/2710 ../class_one/images/val/124_104001001F2A5700_tile_229.png: 512x512 4 3,2,jet,4s, Done. (0.024s)
# image 323/2710 ../class_one/images/val/124_104001001F2A5700_tile_230.png: 512x512 2 2,1,propeller,3s, 2 3,2,jet,4s, Done. (0.024s)
# image 324/2710 ../class_one/images/val/124_104001001F2A5700_tile_247.png: 512x512 6 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.024s)
# image 325/2710 ../class_one/images/val/124_104001001F2A5700_tile_342.png: 512x512 Done. (0.022s)
# image 326/2710 ../class_one/images/val/124_104001001F2A5700_tile_344.png: 512x512 4 0,0,unpowered,1s, 3 2,1,propeller,3s, Done. (0.023s)
# image 327/2710 ../class_one/images/val/124_104001001F2A5700_tile_345.png: 512x512 4 0,0,unpowered,1s, 6 2,1,propeller,3s, Done. (0.023s)
# image 328/2710 ../class_one/images/val/124_104001001F2A5700_tile_359.png: 512x512 1 0,0,unpowered,1s, Done. (0.023s)
# image 329/2710 ../class_one/images/val/124_104001001F2A5700_tile_360.png: 512x512 8 0,0,unpowered,1s, 2 2,1,propeller,3s, Done. (0.023s)
# image 330/2710 ../class_one/images/val/124_104001001F2A5700_tile_361.png: 512x512 10 0,0,unpowered,1s, 3 2,1,propeller,3s, Done. (0.023s)
# image 331/2710 ../class_one/images/val/124_104001001F2A5700_tile_37.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 332/2710 ../class_one/images/val/124_104001001F2A5700_tile_376.png: 512x512 5 0,0,unpowered,1s, Done. (0.022s)
# image 333/2710 ../class_one/images/val/124_104001001F2A5700_tile_377.png: 512x512 6 0,0,unpowered,1s, 1 2,1,propeller,3s, Done. (0.023s)
# image 334/2710 ../class_one/images/val/124_104001001F2A5700_tile_378.png: 512x512 1 0,0,unpowered,1s, 1 2,1,propeller,3s, Done. (0.023s)
# image 335/2710 ../class_one/images/val/124_104001001F2A5700_tile_54.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 336/2710 ../class_one/images/val/124_104001001F2A5700_tile_55.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 337/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1015.png: 512x512 1 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.022s)
# image 338/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1069.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 339/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1070.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 340/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1097.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 341/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1099.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 342/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1100.png: 512x512 2 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.022s)
# image 343/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1125.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 344/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1126.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 345/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1153.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 346/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1154.png: 512x512 2 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.022s)
# image 347/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1209.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 348/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1210.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 349/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1211.png: 512x512 3 3,2,jet,4s, Done. (0.024s)
# image 350/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1212.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 351/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1263.png: 512x512 Done. (0.021s)
# image 352/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1264.png: 512x512 2 3,2,jet,4s, Done. (0.024s)
# image 353/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1268.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 354/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1269.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 355/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1270.png: 512x512 Done. (0.022s)
# image 356/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1316.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 357/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1317.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 358/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1318.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 359/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1319.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 360/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1320.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 361/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1321.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 362/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1323.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 363/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1324.png: 512x512 4 3,2,jet,4s, Done. (0.023s)
# image 364/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1325.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 365/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1371.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 366/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1372.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 367/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1374.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 368/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1375.png: 512x512 3 3,2,jet,4s, Done. (0.022s)
# image 369/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1376.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 370/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1377.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 371/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1378.png: 512x512 3 3,2,jet,4s, Done. (0.023s)
# image 372/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1383.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 373/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1431.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 374/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1432.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 375/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1433.png: 512x512 3 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.023s)
# image 376/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1434.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 377/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1438.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 378/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1439.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 379/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1442.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 380/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1443.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 381/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1486.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 382/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1487.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 383/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1488.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 384/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1490.png: 512x512 1 2,1,propeller,3s, 1 6,4,jet,7s, Done. (0.022s)
# image 385/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1491.png: 512x512 1 6,4,jet,7s, Done. (0.022s)
# image 386/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1492.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 387/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1493.png: 512x512 3 3,2,jet,4s, Done. (0.022s)
# image 388/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1494.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 389/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1495.png: 512x512 2 3,2,jet,4s, Done. (0.023s)
# image 390/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1496.png: 512x512 1 3,2,jet,4s, Done. (0.022s)
# image 391/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1497.png: 512x512 1 3,2,jet,4s, Done. (0.023s)
# image 392/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1541.png: 512x512 2 3,2,jet,4s, Done. (0.022s)
# image 393/2710 ../class_one/images/val/126_104001000C4AEE00_tile_1544.png: 512x512 Done. (0.022s)
# ...
# image 2582/2710 ../class_one/images/val/96_104001003C8C7800_tile_1075.png: 512x512 5 2,1,propeller,3s, Done. (0.021s)
# image 2583/2710 ../class_one/images/val/96_104001003C8C7800_tile_1077.png: 512x512 13 2,1,propeller,3s, Done. (0.022s)
# image 2584/2710 ../class_one/images/val/96_104001003C8C7800_tile_1078.png: 512x512 18 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.021s)
# image 2585/2710 ../class_one/images/val/96_104001003C8C7800_tile_1079.png: 512x512 1 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.021s)
# image 2586/2710 ../class_one/images/val/96_104001003C8C7800_tile_1102.png: 512x512 5 2,1,propeller,3s, Done. (0.021s)
# image 2587/2710 ../class_one/images/val/96_104001003C8C7800_tile_1103.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2588/2710 ../class_one/images/val/96_104001003C8C7800_tile_1104.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2589/2710 ../class_one/images/val/96_104001003C8C7800_tile_1105.png: 512x512 19 2,1,propeller,3s, Done. (0.021s)
# image 2590/2710 ../class_one/images/val/96_104001003C8C7800_tile_1106.png: 512x512 13 2,1,propeller,3s, Done. (0.021s)
# image 2591/2710 ../class_one/images/val/96_104001003C8C7800_tile_1107.png: 512x512 2 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2592/2710 ../class_one/images/val/96_104001003C8C7800_tile_1130.png: 512x512 3 2,1,propeller,3s, Done. (0.022s)
# image 2593/2710 ../class_one/images/val/96_104001003C8C7800_tile_1132.png: 512x512 12 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 2594/2710 ../class_one/images/val/96_104001003C8C7800_tile_1133.png: 512x512 14 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2595/2710 ../class_one/images/val/96_104001003C8C7800_tile_1134.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2596/2710 ../class_one/images/val/96_104001003C8C7800_tile_1157.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2597/2710 ../class_one/images/val/96_104001003C8C7800_tile_1159.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2598/2710 ../class_one/images/val/96_104001003C8C7800_tile_1160.png: 512x512 17 2,1,propeller,3s, Done. (0.021s)
# image 2599/2710 ../class_one/images/val/96_104001003C8C7800_tile_1161.png: 512x512 5 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2600/2710 ../class_one/images/val/96_104001003C8C7800_tile_1162.png: 512x512 2 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2601/2710 ../class_one/images/val/96_104001003C8C7800_tile_1183.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2602/2710 ../class_one/images/val/96_104001003C8C7800_tile_1184.png: 512x512 4 2,1,propeller,3s, Done. (0.022s)
# image 2603/2710 ../class_one/images/val/96_104001003C8C7800_tile_1185.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2604/2710 ../class_one/images/val/96_104001003C8C7800_tile_1187.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2605/2710 ../class_one/images/val/96_104001003C8C7800_tile_1188.png: 512x512 10 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.022s)
# image 2606/2710 ../class_one/images/val/96_104001003C8C7800_tile_1189.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2607/2710 ../class_one/images/val/96_104001003C8C7800_tile_1211.png: 512x512 12 2,1,propeller,3s, Done. (0.021s)
# image 2608/2710 ../class_one/images/val/96_104001003C8C7800_tile_1212.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2609/2710 ../class_one/images/val/96_104001003C8C7800_tile_1238.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2610/2710 ../class_one/images/val/96_104001003C8C7800_tile_1239.png: 512x512 10 2,1,propeller,3s, Done. (0.021s)
# image 2611/2710 ../class_one/images/val/96_104001003C8C7800_tile_1243.png: 512x512 6 2,1,propeller,3s, Done. (0.022s)
# image 2612/2710 ../class_one/images/val/96_104001003C8C7800_tile_1244.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2613/2710 ../class_one/images/val/96_104001003C8C7800_tile_1266.png: 512x512 7 2,1,propeller,3s, Done. (0.021s)
# image 2614/2710 ../class_one/images/val/96_104001003C8C7800_tile_1267.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2615/2710 ../class_one/images/val/96_104001003C8C7800_tile_1270.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2616/2710 ../class_one/images/val/96_104001003C8C7800_tile_1271.png: 512x512 18 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2617/2710 ../class_one/images/val/96_104001003C8C7800_tile_1272.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 2618/2710 ../class_one/images/val/96_104001003C8C7800_tile_1294.png: 512x512 6 2,1,propeller,3s, Done. (0.021s)
# image 2619/2710 ../class_one/images/val/96_104001003C8C7800_tile_1295.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2620/2710 ../class_one/images/val/96_104001003C8C7800_tile_1297.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2621/2710 ../class_one/images/val/96_104001003C8C7800_tile_1298.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2622/2710 ../class_one/images/val/96_104001003C8C7800_tile_1299.png: 512x512 5 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2623/2710 ../class_one/images/val/96_104001003C8C7800_tile_1322.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2624/2710 ../class_one/images/val/96_104001003C8C7800_tile_1325.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2625/2710 ../class_one/images/val/96_104001003C8C7800_tile_1326.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2626/2710 ../class_one/images/val/96_104001003C8C7800_tile_1349.png: 512x512 2 2,1,propeller,3s, Done. (0.022s)
# image 2627/2710 ../class_one/images/val/96_104001003C8C7800_tile_1350.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2628/2710 ../class_one/images/val/96_104001003C8C7800_tile_1352.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, Done. (0.022s)
# image 2629/2710 ../class_one/images/val/96_104001003C8C7800_tile_1353.png: 512x512 2 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2630/2710 ../class_one/images/val/96_104001003C8C7800_tile_1376.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2631/2710 ../class_one/images/val/96_104001003C8C7800_tile_1380.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2632/2710 ../class_one/images/val/96_104001003C8C7800_tile_1404.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2633/2710 ../class_one/images/val/96_104001003C8C7800_tile_1405.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2634/2710 ../class_one/images/val/96_104001003C8C7800_tile_1406.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2635/2710 ../class_one/images/val/96_104001003C8C7800_tile_1407.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2636/2710 ../class_one/images/val/96_104001003C8C7800_tile_1409.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2637/2710 ../class_one/images/val/96_104001003C8C7800_tile_1433.png: 512x512 5 2,1,propeller,3s, Done. (0.021s)
# image 2638/2710 ../class_one/images/val/96_104001003C8C7800_tile_1434.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2639/2710 ../class_one/images/val/96_104001003C8C7800_tile_1435.png: 512x512 1 2,1,propeller,3s, Done. (0.022s)
# image 2640/2710 ../class_one/images/val/96_104001003C8C7800_tile_1437.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2641/2710 ../class_one/images/val/96_104001003C8C7800_tile_1461.png: 512x512 3 2,1,propeller,3s, Done. (0.023s)
# image 2642/2710 ../class_one/images/val/96_104001003C8C7800_tile_1462.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2643/2710 ../class_one/images/val/96_104001003C8C7800_tile_227.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2644/2710 ../class_one/images/val/96_104001003C8C7800_tile_241.png: 512x512 6 3,2,jet,4s, 1 7,4,propeller,8s, Done. (0.022s)
# image 2645/2710 ../class_one/images/val/96_104001003C8C7800_tile_242.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, 4 7,4,propeller,8s, Done. (0.022s)
# image 2646/2710 ../class_one/images/val/96_104001003C8C7800_tile_245.png: 512x512 1 4,2,propeller,5s, Done. (0.022s)
# image 2647/2710 ../class_one/images/val/96_104001003C8C7800_tile_269.png: 512x512 2 3,2,jet,4s, 3 4,2,propeller,5s, 3 7,4,propeller,8s, Done. (0.021s)
# image 2648/2710 ../class_one/images/val/96_104001003C8C7800_tile_270.png: 512x512 3 3,2,jet,4s, 5 4,2,propeller,5s, 3 7,4,propeller,8s, Done. (0.021s)
# image 2649/2710 ../class_one/images/val/96_104001003C8C7800_tile_297.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2650/2710 ../class_one/images/val/96_104001003C8C7800_tile_298.png: 512x512 1 2,1,propeller,3s, 3 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2651/2710 ../class_one/images/val/96_104001003C8C7800_tile_299.png: 512x512 1 3,2,jet,4s, Done. (0.021s)
# image 2652/2710 ../class_one/images/val/96_104001003C8C7800_tile_306.png: 512x512 1 4,2,propeller,5s, Done. (0.021s)
# image 2653/2710 ../class_one/images/val/96_104001003C8C7800_tile_325.png: 512x512 1 4,2,propeller,5s, Done. (0.021s)
# image 2654/2710 ../class_one/images/val/96_104001003C8C7800_tile_326.png: 512x512 1 2,1,propeller,3s, 1 3,2,jet,4s, 2 4,2,propeller,5s, Done. (0.021s)
# image 2655/2710 ../class_one/images/val/96_104001003C8C7800_tile_327.png: 512x512 1 4,2,propeller,5s, Done. (0.021s)
# image 2656/2710 ../class_one/images/val/96_104001003C8C7800_tile_354.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2657/2710 ../class_one/images/val/96_104001003C8C7800_tile_379.png: 512x512 2 4,2,propeller,5s, Done. (0.021s)
# image 2658/2710 ../class_one/images/val/96_104001003C8C7800_tile_380.png: 512x512 1 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2659/2710 ../class_one/images/val/96_104001003C8C7800_tile_407.png: 512x512 3 4,2,propeller,5s, Done. (0.021s)
# image 2660/2710 ../class_one/images/val/96_104001003C8C7800_tile_408.png: 512x512 3 4,2,propeller,5s, Done. (0.022s)
# image 2661/2710 ../class_one/images/val/96_104001003C8C7800_tile_51.png: 512x512 1 3,2,jet,4s, 1 6,4,jet,7s, Done. (0.022s)
# image 2662/2710 ../class_one/images/val/96_104001003C8C7800_tile_600.png: 512x512 1 3,2,jet,4s, Done. (0.021s)
# image 2663/2710 ../class_one/images/val/96_104001003C8C7800_tile_601.png: 512x512 1 3,2,jet,4s, Done. (0.021s)
# image 2664/2710 ../class_one/images/val/96_104001003C8C7800_tile_627.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2665/2710 ../class_one/images/val/96_104001003C8C7800_tile_628.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2666/2710 ../class_one/images/val/96_104001003C8C7800_tile_629.png: 512x512 1 3,2,jet,4s, Done. (0.021s)
# image 2667/2710 ../class_one/images/val/96_104001003C8C7800_tile_654.png: 512x512 Done. (0.020s)
# image 2668/2710 ../class_one/images/val/96_104001003C8C7800_tile_655.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2669/2710 ../class_one/images/val/96_104001003C8C7800_tile_683.png: 512x512 2 4,2,propeller,5s, 2 7,4,propeller,8s, Done. (0.021s)
# image 2670/2710 ../class_one/images/val/96_104001003C8C7800_tile_711.png: 512x512 3 3,2,jet,4s, 3 4,2,propeller,5s, 1 7,4,propeller,8s, Done. (0.021s)
# image 2671/2710 ../class_one/images/val/96_104001003C8C7800_tile_720.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2672/2710 ../class_one/images/val/96_104001003C8C7800_tile_721.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2673/2710 ../class_one/images/val/96_104001003C8C7800_tile_749.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2674/2710 ../class_one/images/val/96_104001003C8C7800_tile_776.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2675/2710 ../class_one/images/val/96_104001003C8C7800_tile_777.png: 512x512 7 2,1,propeller,3s, Done. (0.021s)
# image 2676/2710 ../class_one/images/val/96_104001003C8C7800_tile_792.png: 512x512 Done. (0.020s)
# image 2677/2710 ../class_one/images/val/96_104001003C8C7800_tile_820.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, 5 7,4,propeller,8s, Done. (0.021s)
# image 2678/2710 ../class_one/images/val/96_104001003C8C7800_tile_821.png: 512x512 1 7,4,propeller,8s, Done. (0.021s)
# image 2679/2710 ../class_one/images/val/96_104001003C8C7800_tile_830.png: 512x512 8 2,1,propeller,3s, Done. (0.021s)
# image 2680/2710 ../class_one/images/val/96_104001003C8C7800_tile_831.png: 512x512 8 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2681/2710 ../class_one/images/val/96_104001003C8C7800_tile_848.png: 512x512 1 3,2,jet,4s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2682/2710 ../class_one/images/val/96_104001003C8C7800_tile_854.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2683/2710 ../class_one/images/val/96_104001003C8C7800_tile_858.png: 512x512 18 2,1,propeller,3s, Done. (0.021s)
# image 2684/2710 ../class_one/images/val/96_104001003C8C7800_tile_859.png: 512x512 5 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.021s)
# image 2685/2710 ../class_one/images/val/96_104001003C8C7800_tile_881.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2686/2710 ../class_one/images/val/96_104001003C8C7800_tile_882.png: 512x512 9 2,1,propeller,3s, Done. (0.021s)
# image 2687/2710 ../class_one/images/val/96_104001003C8C7800_tile_885.png: 512x512 12 2,1,propeller,3s, Done. (0.021s)
# image 2688/2710 ../class_one/images/val/96_104001003C8C7800_tile_886.png: 512x512 9 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2689/2710 ../class_one/images/val/96_104001003C8C7800_tile_887.png: 512x512 3 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2690/2710 ../class_one/images/val/96_104001003C8C7800_tile_909.png: 512x512 7 2,1,propeller,3s, Done. (0.021s)
# image 2691/2710 ../class_one/images/val/96_104001003C8C7800_tile_910.png: 512x512 6 2,1,propeller,3s, Done. (0.021s)
# image 2692/2710 ../class_one/images/val/96_104001003C8C7800_tile_913.png: 512x512 11 2,1,propeller,3s, Done. (0.021s)
# image 2693/2710 ../class_one/images/val/96_104001003C8C7800_tile_914.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2694/2710 ../class_one/images/val/96_104001003C8C7800_tile_930.png: 512x512 1 4,2,propeller,5s, Done. (0.021s)
# image 2695/2710 ../class_one/images/val/96_104001003C8C7800_tile_937.png: 512x512 11 2,1,propeller,3s, Done. (0.021s)
# image 2696/2710 ../class_one/images/val/96_104001003C8C7800_tile_938.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2697/2710 ../class_one/images/val/96_104001003C8C7800_tile_940.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2698/2710 ../class_one/images/val/96_104001003C8C7800_tile_941.png: 512x512 1 2,1,propeller,3s, 6 4,2,propeller,5s, Done. (0.021s)
# image 2699/2710 ../class_one/images/val/96_104001003C8C7800_tile_942.png: 512x512 2 4,2,propeller,5s, Done. (0.021s)
# image 2700/2710 ../class_one/images/val/96_104001003C8C7800_tile_958.png: 512x512 1 4,2,propeller,5s, Done. (0.021s)
# image 2701/2710 ../class_one/images/val/96_104001003C8C7800_tile_964.png: 512x512 2 2,1,propeller,3s, Done. (0.021s)
# image 2702/2710 ../class_one/images/val/96_104001003C8C7800_tile_965.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2703/2710 ../class_one/images/val/96_104001003C8C7800_tile_967.png: 512x512 12 2,1,propeller,3s, Done. (0.022s)
# image 2704/2710 ../class_one/images/val/96_104001003C8C7800_tile_968.png: 512x512 18 2,1,propeller,3s, 1 4,2,propeller,5s, Done. (0.021s)
# image 2705/2710 ../class_one/images/val/96_104001003C8C7800_tile_969.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2706/2710 ../class_one/images/val/96_104001003C8C7800_tile_992.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# image 2707/2710 ../class_one/images/val/96_104001003C8C7800_tile_993.png: 512x512 1 2,1,propeller,3s, Done. (0.021s)
# image 2708/2710 ../class_one/images/val/96_104001003C8C7800_tile_995.png: 512x512 4 2,1,propeller,3s, Done. (0.021s)
# image 2709/2710 ../class_one/images/val/96_104001003C8C7800_tile_996.png: 512x512 16 2,1,propeller,3s, 2 4,2,propeller,5s, Done. (0.021s)
# image 2710/2710 ../class_one/images/val/96_104001003C8C7800_tile_997.png: 512x512 3 2,1,propeller,3s, Done. (0.021s)
# Results saved to /home/ubuntu/src/yolo_planes/yolov5/inference/output
# Done. (133.491s)

# %%
# !mv ./inference/output ./inference/class_one_out

# %% [markdown]
# The following command is used to find preliminary resutls. It outputs the precision, recall, and mean average precision by class for the tiled images. For the most accurate resutls, though, we will need to combine the tiled image predictions and compare with the original images. In notebooks 2 and 3, we will complete teh model evaluation pipeline.

# %%
# !python test.py --weights ./runs/class_one_yolov5l/weights/best_yolov5l_rareplanes.pt --data ./data/class_one.yaml --img 512 --verbose --conf-thres 0.4
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.4, data='./data/class_one.yaml', device='', img_size=512, iou_thres=0.65, merge=False, save_json=False, single_cls=False, task='val', verbose=True, weights=['./runs/class_one_yolov5l/weights/best_yolov5l_rareplanes.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16160MB)
#
# Fusing layers... Model Summary: 236 layers, 4.74024e+07 parameters, 4.48868e+07 gradients
# Scanning labels ../class_one/labels/val.cache (2710 found, 0 missing, 0 empty, 0
#                Class      Images     Targets           P           R      mAP@.5
#                  all    2.71e+03    6.81e+03        0.64        0.65       0.615       0.481
#      0,0,unpowered,1    2.71e+03          61       0.734        0.77       0.767       0.557
#            1,1,jet,2    2.71e+03          78       0.449       0.282       0.204      0.0925
#      2,1,propeller,3    2.71e+03    2.15e+03       0.926       0.919       0.901       0.703
#            3,2,jet,4    2.71e+03    3.22e+03       0.916       0.958       0.948       0.808
#      4,2,propeller,5    2.71e+03         949       0.846       0.867        0.84       0.674
#            5,3,jet,6    2.71e+03           3           0           0           0           0
#            6,4,jet,7    2.71e+03         223        0.63       0.686       0.618       0.517
#      7,4,propeller,8    2.71e+03         127       0.619       0.717       0.643       0.494
# Speed: 2.6/1.3/3.9 ms inference/NMS/total per 512x512 image at batch-size 32

# %% [markdown]
# Now, please head to the notebook titled `2_yolo_post_processing`.
