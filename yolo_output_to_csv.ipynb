# %%
## Run detect.py, set save_txt to True, run this then on the the output of that
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
from shapely.geometry import box
import shapely.wkt
from shapely.wkt import loads
from tqdm import tqdm
import pandas as pd
import os
import sys
import numpy as np
import glob
from solaris.vector.polygon import convert_poly_coords
from solaris.vector.mask import mask_to_poly_geojson
from solaris.utils.geo import get_crs
import gdal

# %%
def non_max_suppression(boxes, probs=[], overlapThresh=0.5):
    """
    Apply non-max suppression.
    Directly from:
    https://github.com/CosmiQ/simrdwn/
    http://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
    Malisiewicz et al.
    see modular_sliding_window.py, functions non_max_suppression, \
            non_max_supression_rot
    Arguments
    ---------
    boxes : np.array
        Prediction boxes with the format: [[xmin, ymin, xmax, ymax], [...] ]
    probs : np.array
        Array of prediction scores or probabilities.  If [], ignore.  If not
        [], sort boxes by probability prior to applying non-max suppression.
        Defaults to ``[]``.
    overlapThresh : float
        minimum IOU overlap to retain.  Defaults to ``0.5``.
    Returns
    -------
    pick : np.array
        Array of indices to keep
    """

    print("Executing non-max suppression...")
    len_init = len(boxes)

    # if there are no boxes, return an empty list
    if len(boxes) == 0:
        return [], [], []

    # boxes_tot = boxes  # np.asarray(boxes)
    boxes = np.asarray([b[:4] for b in boxes])
    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")

    # initialize the list of picked indexes
    pick = []

    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]
    # compute the area of the bounding boxes
    area = (x2 - x1) * (y2 - y1)

    # sort the boxes by the bottom-right y-coordinate of the bounding box
    if len(probs) == 0:
        idxs = np.argsort(((x2 - x1) * (y2 - y1)))
    # sort boxes by the highest prob (descending order)
    else:
        idxs = np.argsort(probs)[::-1]

    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        # find the largest (x, y) coordinates for the start of
        # the bounding box and the smallest (x, y) coordinates
        # for the end of the bounding box
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])

        # compute the width and height of the bounding box
        w = np.maximum(0, xx2 - xx1)
        h = np.maximum(0, yy2 - yy1)

        # compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]

        # delete all indexes from the index list that have
        idxs = np.delete(
            idxs,
            np.concatenate(([last], np.where(overlap > overlapThresh)[0])))

    print("  non-max suppression init boxes:", len_init)
    print("  non-max suppression final boxes:", len(pick))
    return pick

def vectorize_yolo(df, output_dir, nms=True, overlapThresh=0.5):
    # Create directory
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    bb_dir = os.path.join(output_dir, "bounding_boxes")
    if not os.path.exists(bb_dir):
        os.makedirs(bb_dir)
    try:
        df['bb_geometry'] = df['bb_geometry'].apply(loads)
    except AttributeError:
        pass
    for img_id in df['image'].unique():
        img_df = df[df['image'] == img_id]
        img_df = img_df.reset_index()
        crs = str('EPSG:' + img_df['crs'].iloc[0])
        if nms is True:
            confs = []
            bbs = []
            for bb_geom in img_df['bb_geometry']:
                bb_geom = [bb_geom.bounds[0],bb_geom.bounds[1],bb_geom.bounds[2],bb_geom.bounds[3]]
                bbs.append(bb_geom)
            b_box_nms_indices = non_max_suppression(bbs, confs, overlapThresh=overlapThresh)
            b_box_df_out = gpd.GeoDataFrame(img_df.loc[b_box_nms_indices], crs=crs, geometry=img_df.bb_geometry)
            b_box_df_out = b_box_df_out.drop(columns=["bb_geometry", "crs", 'index'])
        else:
            b_box_df_out = gpd.GeoDataFrame(img_df, crs=crs, geometry=img_df.bb_geometry)
            b_box_df_out = b_box_df_out.drop(columns=["bb_geometry", "crs", 'index'])
        output = os.path.join(bb_dir, img_id.split(".")[0] + ".geojson")
        b_box_df_out.to_file(output, driver='GeoJSON')

# %%
input_dir = "/local_data/cosmiq/src/achadda/yolo_planes/yolov5/inference/class_four_out"
output_dir = input_dir
image_dir = "/local_data/cosmiq/src/achadda/yolo_planes/class_four/images/val"
lookup_table = "/local_data/cosmiq/src/achadda/yolo_planes/geojsons_test/yolo_class_four/custom_class_lookup.csv"
lookup_table = pd.read_csv(lookup_table)
lookup_table['yolo'] = lookup_table['custom_id'] - 1
lookup_table.set_index('yolo')
#lookup_table['num_tail_fins,wing_position,wing_type][0]
print(lookup_table)
# Out:
#      Unnamed: 0                             role  num_engines propulsion  \
# 0             0    Large Civil Transport/Utility            2        jet
# 1             1    Large Civil Transport/Utility            2        jet
# 2             2    Large Civil Transport/Utility            2        jet
# 3             3    Large Civil Transport/Utility            2        jet
# 4             4    Large Civil Transport/Utility            2        jet
# 5             5    Large Civil Transport/Utility            3        jet
# 6             6    Large Civil Transport/Utility            4        jet
# 7             7    Large Civil Transport/Utility            4        jet
# 8             8    Large Civil Transport/Utility            4        jet
# 9             9    Large Civil Transport/Utility            4        jet
# 10           10    Large Civil Transport/Utility            4  propeller
# 11           11    Large Civil Transport/Utility            4  propeller
# 12           12   Medium Civil Transport/Utility            0  unpowered
# 13           13   Medium Civil Transport/Utility            0  unpowered
# 14           14   Medium Civil Transport/Utility            0  unpowered
# 15           15   Medium Civil Transport/Utility            0  unpowered
# 16           16   Medium Civil Transport/Utility            0  unpowered
# 17           17   Medium Civil Transport/Utility            1  propeller
# 18           18   Medium Civil Transport/Utility            1  propeller
# 19           19   Medium Civil Transport/Utility            2        jet
# 20           20   Medium Civil Transport/Utility            2        jet
# 21           21   Medium Civil Transport/Utility            2        jet
# 22           22   Medium Civil Transport/Utility            2        jet
# 23           23   Medium Civil Transport/Utility            2        jet
# 24           24   Medium Civil Transport/Utility            2        jet
# 25           25   Medium Civil Transport/Utility            2        jet
# 26           26   Medium Civil Transport/Utility            2  propeller
# 27           27   Medium Civil Transport/Utility            2  propeller
# 28           28   Medium Civil Transport/Utility            2  propeller
# 29           29   Medium Civil Transport/Utility            2  propeller
# ..          ...                              ...          ...        ...
# 80           80  Military Transport/Utility/AWAC            2  propeller
# 81           81  Military Transport/Utility/AWAC            4        jet
# 82           82  Military Transport/Utility/AWAC            4        jet
# 83           83  Military Transport/Utility/AWAC            4        jet
# 84           84  Military Transport/Utility/AWAC            4        jet
# 85           85  Military Transport/Utility/AWAC            4  propeller
# 86           86  Military Transport/Utility/AWAC            4  propeller
# 87           87  Military Transport/Utility/AWAC            4  propeller
# 88           88  Military Transport/Utility/AWAC            4  propeller
# 89           89  Military Transport/Utility/AWAC            4  propeller
# 90           90  Military Transport/Utility/AWAC            4  propeller
# 91           91    Small Civil Transport/Utility            0  unpowered
# 92           92    Small Civil Transport/Utility            0  unpowered
# 93           93    Small Civil Transport/Utility            1  propeller
# 94           94    Small Civil Transport/Utility            1  propeller
# 95           95    Small Civil Transport/Utility            1  propeller
# 96           96    Small Civil Transport/Utility            1  propeller
# 97           97    Small Civil Transport/Utility            1  propeller
# 98           98    Small Civil Transport/Utility            1  propeller
# 99           99    Small Civil Transport/Utility            2        jet
# 100         100    Small Civil Transport/Utility            2        jet
# 101         101    Small Civil Transport/Utility            2        jet
# 102         102    Small Civil Transport/Utility            2        jet
# 103         103    Small Civil Transport/Utility            2  propeller
# 104         104    Small Civil Transport/Utility            2  propeller
# 105         105    Small Civil Transport/Utility            2  propeller
# 106         106    Small Civil Transport/Utility            2  propeller
# 107         107    Small Civil Transport/Utility            2  propeller
# 108         108    Small Civil Transport/Utility            2  propeller
# 109         109    Small Civil Transport/Utility            2  propeller
#
#     canards  num_tail_fins    wing_position wing_type  faa_wingspan_class  \
# 0        no              1  mid/low mounted  straight                   4
# 1        no              1  mid/low mounted  straight                   5
# 2        no              1  mid/low mounted     swept                   4
# 3        no              1  mid/low mounted     swept                   5
# 4        no              1  mid/low mounted     swept                   6
# 5        no              1  mid/low mounted     swept                   4
# 6        no              1     high mounted     swept                   4
# 7        no              1  mid/low mounted     swept                   4
# 8        no              1  mid/low mounted     swept                   5
# 9        no              1  mid/low mounted     swept                   6
# 10       no              1     high mounted  straight                   4
# 11       no              1  mid/low mounted  straight                   4
# 12       no              1     high mounted  straight                   2
# 13       no              1  mid/low mounted  straight                   2
# 14       no              1  mid/low mounted  straight                   3
# 15       no              1  mid/low mounted     swept                   2
# 16       no              1  mid/low mounted     swept                   3
# 17       no              1     high mounted  straight                   2
# 18       no              1  mid/low mounted  straight                   2
# 19       no              1     high mounted  straight                   2
# 20       no              1     high mounted     swept                   2
# 21       no              1  mid/low mounted     delta                   3
# 22       no              1  mid/low mounted  straight                   2
# 23       no              1  mid/low mounted  straight                   3
# 24       no              1  mid/low mounted     swept                   2
# 25       no              1  mid/low mounted     swept                   3
# 26       no              1     high mounted  straight                   2
# 27       no              1     high mounted  straight                   3
# 28       no              1  mid/low mounted  straight                   2
# 29       no              1  mid/low mounted  straight                   3
# ..      ...            ...              ...       ...                 ...
# 80       no              2  mid/low mounted  straight                   2
# 81       no              1     high mounted     swept                   4
# 82       no              1     high mounted     swept                   6
# 83       no              1  mid/low mounted     swept                   4
# 84       no              1  mid/low mounted     swept                   5
# 85       no              1     high mounted  straight                   4
# 86       no              1     high mounted     swept                   4
# 87       no              1  mid/low mounted  straight                   3
# 88       no              1  mid/low mounted  straight                   4
# 89       no              2     high mounted  straight                   3
# 90       no              2  mid/low mounted  straight                   4
# 91       no              1     high mounted  straight                   1
# 92       no              1  mid/low mounted  straight                   1
# 93       no              1     high mounted  straight                   1
# 94       no              1  mid/low mounted  straight                   1
# 95       no              2     high mounted  straight                   1
# 96       no              2  mid/low mounted  straight                   1
# 97      yes              2     high mounted     swept                   1
# 98      yes              2  mid/low mounted     swept                   1
# 99       no              1  mid/low mounted  straight                   1
# 100      no              1  mid/low mounted     swept                   1
# 101     yes              1     high mounted  straight                   1
# 102     yes              1  mid/low mounted  straight                   1
# 103      no              1     high mounted  straight                   1
# 104      no              1  mid/low mounted  straight                   1
# 105      no              2     high mounted  straight                   1
# 106      no              2  mid/low mounted  straight                   1
# 107     yes              1  mid/low mounted  straight                   1
# 108     yes              1  mid/low mounted     swept                   1
# 109     yes              2  mid/low mounted     swept                   1
#
#      custom_id  yolo
# 0            1     0
# 1            2     1
# 2            3     2
# 3            4     3
# 4            5     4
# 5            6     5
# 6            7     6
# 7            8     7
# 8            9     8
# 9           10     9
# 10          11    10
# 11          12    11
# 12          13    12
# 13          14    13
# 14          15    14
# 15          16    15
# 16          17    16
# 17          18    17
# 18          19    18
# 19          20    19
# 20          21    20
# 21          22    21
# 22          23    22
# 23          24    23
# 24          25    24
# 25          26    25
# 26          27    26
# 27          28    27
# 28          29    28
# 29          30    29
# ..         ...   ...
# 80          81    80
# 81          82    81
# 82          83    82
# 83          84    83
# 84          85    84
# 85          86    85
# 86          87    86
# 87          88    87
# 88          89    88
# 89          90    89
# 90          91    90
# 91          92    91
# 92          93    92
# 93          94    93
# 94          95    94
# 95          96    95
# 96          97    96
# 97          98    97
# 98          99    98
# 99         100    99
# 100        101   100
# 101        102   101
# 102        103   102
# 103        104   103
# 104        105   104
# 105        106   105
# 106        107   106
# 107        108   107
# 108        109   108
# 109        110   109
#
# [110 rows x 11 columns]

# %%
class_ids = []
classes = []
confidences = []
images = []
crs_s = []
bb_geoms = []
os.chdir(input_dir)
txts = glob.glob("*.txt")
for txt in tqdm(txts):
    image = txt.split(".")[0] + ".png"
    im_path = os.path.join(image_dir, image)
    image = image.split("_tile")[0]
    df = pd.read_csv(txt,header = None, sep = " ")
    for index, row in df.iterrows():
        b_box = box(row[0], row[1], row[2], row[3])
        bb_geom = convert_poly_coords(b_box, raster_src=im_path)
        bb_geoms.append(bb_geom)
        crs = get_crs(gdal.Open(im_path))
        crs = str(crs)
        crs_s.append(crs)
        class_ids.append(row[0])
        confidences.append(row[5])
        images.append(image)
        classes.append(str(lookup_table['role'][row[0]]) + ' ' + str(lookup_table['num_engines'][row[0]]) + ' ' + str(lookup_table['propulsion'][row[0]]) + ' ' + str(lookup_table['canards'][row[0]]) + ' ' + str(lookup_table['num_tail_fins'][row[0]]) + ' ' + str(lookup_table['wing_position'][row[0]]) + ' ' + str(lookup_table['wing_type'][row[0]]) + ' ' + str(lookup_table['faa_wingspan_class'][row[0]]))
        
dict = {'class_id': class_ids, 'class': classes, 'confidence': confidences, 'image': images, 'crs': crs_s, 'bb_geometry': bb_geoms}
df = pd.DataFrame(dict)
# Out:
#
#
#  87%|████████▋ | 2297/2643 [00:28<00:04, 72.39it/s]
#
#
#  87%|████████▋ | 2307/2643 [00:29<00:04, 78.83it/s]
#
#
#  88%|████████▊ | 2317/2643 [00:29<00:04, 81.49it/s]
#
#
#  88%|████████▊ | 2328/2643 [00:29<00:03, 88.21it/s]
#
#
#  89%|████████▊ | 2340/2643 [00:29<00:03, 93.74it/s]
#
#
#  89%|████████▉ | 2351/2643 [00:29<00:03, 94.22it/s]
#
#
#  89%|████████▉ | 2361/2643 [00:29<00:02, 95.00it/s]
#
#
#  90%|████████▉ | 2371/2643 [00:29<00:02, 95.39it/s]
#
#
#  90%|█████████ | 2381/2643 [00:29<00:02, 94.97it/s]
#
#
#  90%|█████████ | 2391/2643 [00:29<00:02, 86.19it/s]
#
#
#  91%|█████████ | 2400/2643 [00:30<00:03, 79.34it/s]
#
#
#  91%|█████████▏| 2413/2643 [00:30<00:02, 89.11it/s]
#
#
#  92%|█████████▏| 2425/2643 [00:30<00:02, 96.49it/s]
#
#
#  92%|█████████▏| 2436/2643 [00:30<00:03, 59.85it/s]
#
#
#  93%|█████████▎| 2445/2643 [00:30<00:03, 61.77it/s]
#
#
#  93%|█████████▎| 2453/2643 [00:30<00:02, 64.93it/s]
#
#
#  93%|█████████▎| 2461/2643 [00:31<00:02, 63.25it/s]
#
#
#  93%|█████████▎| 2470/2643 [00:31<00:02, 68.62it/s]
#
#
#  94%|█████████▍| 2478/2643 [00:31<00:02, 60.94it/s]
#
#
#  94%|█████████▍| 2485/2643 [00:31<00:02, 57.73it/s]
#
#
#  94%|█████████▍| 2492/2643 [00:31<00:02, 59.77it/s]
#
#
#  95%|█████████▍| 2499/2643 [00:31<00:02, 60.53it/s]
#
#
#  95%|█████████▍| 2506/2643 [00:31<00:02, 56.81it/s]
#
#
#  95%|█████████▌| 2513/2643 [00:31<00:02, 59.13it/s]
#  95%|█████████▌| 2522/2643 [00:31<00:01, 63.73it/s]
#
#
#  96%|█████████▌| 2531/2643 [00:32<00:01, 68.98it/s]
#
#
#  96%|█████████▌| 2540/2643 [00:32<00:01, 72.61it/s]
#
#
#  97%|█████████▋| 2552/2643 [00:32<00:01, 81.99it/s]
#
#
#  97%|█████████▋| 2561/2643 [00:32<00:01, 78.51it/s]
#
#
#  97%|█████████▋| 2570/2643 [00:32<00:00, 79.15it/s]
#
#
#  98%|█████████▊| 2579/2643 [00:32<00:00, 78.63it/s]
#
#
#  98%|█████████▊| 2588/2643 [00:32<00:00, 72.27it/s]
#
#
#  98%|█████████▊| 2596/2643 [00:32<00:00, 74.04it/s]
#
#
#  99%|█████████▊| 2605/2643 [00:33<00:00, 77.85it/s]
#
#
#  99%|█████████▉| 2614/2643 [00:33<00:00, 78.07it/s]
#
#
#  99%|█████████▉| 2625/2643 [00:33<00:00, 83.26it/s]
#
#
# 100%|██████████| 2643/2643 [00:33<00:00, 78.95it/s]

# %%
df.to_csv(path_or_buf=os.path.join(output_dir, "detection_results.csv"))

# %%
vectorize_yolo(df, output_dir, nms=True, overlapThresh=0.5)
# Out:
# Executing non-max suppression...
#   non-max suppression init boxes: 694
#   non-max suppression final boxes: 197
# Executing non-max suppression...
#   non-max suppression init boxes: 247
#   non-max suppression final boxes: 99
# Executing non-max suppression...
#   non-max suppression init boxes: 172
#   non-max suppression final boxes: 33
# Executing non-max suppression...
#   non-max suppression init boxes: 123
#   non-max suppression final boxes: 97
# Executing non-max suppression...
#   non-max suppression init boxes: 311
#   non-max suppression final boxes: 222
# Executing non-max suppression...
#   non-max suppression init boxes: 141
#   non-max suppression final boxes: 87
# Executing non-max suppression...
#   non-max suppression init boxes: 362
#   non-max suppression final boxes: 270
# Executing non-max suppression...
#   non-max suppression init boxes: 37
#   non-max suppression final boxes: 9
# Executing non-max suppression...
#   non-max suppression init boxes: 356
#   non-max suppression final boxes: 202
# Executing non-max suppression...
#   non-max suppression init boxes: 15
#   non-max suppression final boxes: 8
# Executing non-max suppression...
#   non-max suppression init boxes: 71
#   non-max suppression final boxes: 25
# Executing non-max suppression...
#   non-max suppression init boxes: 101
#   non-max suppression final boxes: 62
# Executing non-max suppression...
#   non-max suppression init boxes: 226
#   non-max suppression final boxes: 30
# Executing non-max suppression...
#   non-max suppression init boxes: 108
#   non-max suppression final boxes: 26
# Executing non-max suppression...
#   non-max suppression init boxes: 18
#   non-max suppression final boxes: 3
# Executing non-max suppression...
#   non-max suppression init boxes: 228
#   non-max suppression final boxes: 44
# Executing non-max suppression...
#   non-max suppression init boxes: 108
#   non-max suppression final boxes:
# /opt/conda/envs/solaris/lib/python3.6/site-packages/ipykernel_launcher.py:80: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/envs/solaris/lib/python3.6/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in greater
# 84
# Executing non-max suppression...
#   non-max suppression init boxes: 147
#   non-max suppression final boxes: 64
# Executing non-max suppression...
#   non-max suppression init boxes: 64
#   non-max suppression final boxes: 49
# Executing non-max suppression...
#   non-max suppression init boxes: 259
#   non-max suppression final boxes: 165
# Executing non-max suppression...
#   non-max suppression init boxes: 143
#   non-max suppression final boxes: 76
# Executing non-max suppression...
#   non-max suppression init boxes: 231
#   non-max suppression final boxes: 121
# Executing non-max suppression...
#   non-max suppression init boxes: 119
#   non-max suppression final boxes: 32
# Executing non-max suppression...
#   non-max suppression init boxes: 141
#   non-max suppression final boxes: 98
# Executing non-max suppression...
#   non-max suppression init boxes: 144
#   non-max suppression final boxes: 87
# Executing non-max suppression...
#   non-max suppression init boxes: 26
#   non-max suppression final boxes: 11
# Executing non-max suppression...
#   non-max suppression init boxes: 184
#   non-max suppression final boxes: 89
# Executing non-max suppression...
#   non-max suppression init boxes: 41
#   non-max suppression final boxes: 23
# Executing non-max suppression...
#   non-max suppression init boxes: 85
#   non-max suppression final boxes: 56
# Executing non-max suppression...
#   non-max suppression init boxes: 353
#   non-max suppression final boxes: 119
# Executing non-max suppression...
#   non-max suppression init boxes: 120
#   non-max suppression final boxes: 29
# Executing non-max suppression...
#   non-max suppression init boxes: 97
#   non-max suppression final boxes: 66
# Executing non-max suppression...
#   non-max suppression init boxes: 147
#   non-max suppression final boxes: 86
# Executing non-max suppression...
#   non-max suppression init boxes: 33
#   non-max suppression final boxes: 11
# Executing non-max suppression...
#   non-max suppression init boxes: 80
#   non-max suppression final boxes: 54
# Executing non-max suppression...
#   non-max suppression init boxes: 102
#   non-max suppression final boxes: 74
# Executing non-max suppression...
#   non-max suppression init boxes: 13
#   non-max suppression final boxes: 11
# Executing non-max suppression...
#   non-max suppression init boxes: 6
#   non-max suppression final boxes: 4
# Executing non-max suppression...
#   non-max suppression init boxes: 75
#   non-max suppression final boxes: 23
# Executing non-max suppression...
#   non-max suppression init boxes: 61
#   non-max suppression final boxes: 9
# Executing non-max suppression...
#   non-max suppression init boxes: 47
#   non-max suppression final boxes: 14
# Executing non-max suppression...
#   non-max suppression init boxes: 157
#   non-max suppression final boxes: 59
# Executing non-max suppression...
#   non-max suppression init boxes: 32
#   non-max suppression final boxes: 8
# Executing non-max suppression...
#   non-max suppression init boxes: 37
#   non-max suppression final boxes: 24
# Executing non-max suppression...
#   non-max suppression init boxes: 67
#   non-max suppression final boxes: 28
# Executing non-max suppression...
#   non-max suppression init boxes: 12
#   non-max suppression final boxes: 6
# Executing non-max suppression...
#   non-max suppression init boxes: 32
#   non-max suppression final boxes: 21
# Executing non-max suppression...
#   non-max suppression init boxes: 49
#   non-max suppression final boxes: 18
# Executing non-max suppression...
#   non-max suppression init boxes: 40
#   non-max suppression final boxes: 21
# Executing non-max suppression...
#   non-max suppression init boxes: 29
#   non-max suppression final boxes: 14
# Executing non-max suppression...
#   non-max suppression init boxes: 25
#   non-max suppression final boxes: 14
# Executing non-max suppression...
#   non-max suppression init boxes: 24
#   non-max suppression final boxes: 17
# Executing non-max suppression...
#   non-max suppression init boxes: 21
#   non-max suppression final boxes: 10
# Executing non-max suppression...
#   non-max suppression init boxes: 47
#   non-max suppression final boxes: 11
# Executing non-max suppression...
#   non-max suppression init boxes: 27
#   non-max suppression final boxes: 6
# Executing non-max suppression...
#   non-max suppression init boxes: 26
#   non-max suppression final boxes: 7
# Executing non-max suppression...
#   non-max suppression init boxes: 39
#   non-max suppression final boxes: 14
# Executing non-max suppression...
#   non-max suppression init boxes: 25
#   non-max suppression final boxes: 13
# Executing non-max suppression...
#   non-max suppression init boxes: 49
#   non-max suppression final boxes: 18
# Executing non-max suppression...
#   non-max suppression init boxes: 28
#   non-max suppression final boxes: 12
# Executing non-max suppression...
#   non-max suppression init boxes: 7
#   non-max suppression final boxes: 4
# Executing non-max suppression...
#   non-max suppression init boxes: 30
#   non-max suppression final boxes: 8
# Executing non-max suppression...
#   non-max suppression init boxes: 56
#   non-max suppression final boxes: 20
# Executing non-max suppression...
#   non-max suppression init boxes: 60
#   non-max suppression final boxes: 18
# Executing non-max suppression...
#   non-max suppression init boxes: 10
#   non-max suppression final boxes: 7
# Executing non-max suppression...
#   non-max suppression init boxes: 40
#   non-max suppression final boxes: 7
